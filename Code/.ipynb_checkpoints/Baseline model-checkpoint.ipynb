# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score

import thesis_helper
functions = thesis_helper.Thesis_Helper()

from gensim.models import Word2Vec
import gensim.downloader as api
word2vec = api.load("glove-wiki-gigaword-300")

# %%
path_context = "/Users/ivowings/Sync/Thesis/Datasources/Preprocessed/n-grams context/Annotated/sentence_trigrams_context_excelsubset.csv"
path_context2 = "/Users/ivowings/Sync/Thesis/Datasources/Preprocessed/n-grams context/Annotated/sentence_trigrams_context_excelsubset2.csv"
path_trigrams = "/Users/ivowings/Sync/Thesis/Datasources/Preprocessed/n-grams/Annotated/emscad_trigrams_taxonomy.csv"

path_trigrams_lemmatized = "/Users/ivowings/Sync/Thesis/Datasources/Preprocessed/n-grams/Annotated/emscad_trigrams_lemmatized_taxonomy.csv"
path_context_lemmatized = "/Users/ivowings/Sync/Thesis/Datasources/Preprocessed/n-grams context/Annotated/sentence_trigrams_context_lemmatized.csv"

pre_annotated__softskills = '/Users/ivowings/Sync/Thesis/Datasources/Skills/Pre annotated soft skills/annotated_soft_skills_context.csv'

# %%
df_context =  pd.read_csv(path_context,';')
df_context2 =  pd.read_csv(path_context2,';')

df_trigrams = pd.read_csv(path_trigrams, sep=';')

df_trigrams = df_trigrams.rename(columns={'allgrams':'recovered_gram'})

df_preannotated = pd.read_csv(pre_annotated__softskills)
import spacy
nlp = spacy.load("en_core_web_sm")
df_preannotated['length'] = df_preannotated['recovered_gram'].progress_apply(nlp)
df_preannotated['length'] = df_preannotated['length'].progress_apply(len)
df_preannotated = df_preannotated[df_preannotated.length<=3]
df_preannotated = df_preannotated.drop(columns=['length'])

df = pd.concat([df_preannotated,
                df_trigrams,
                df_context,
                df_context2
               ]).reset_index(drop=True)

df['left_context'] = df['left_context'].fillna('empty')
df['right_context'] = df['right_context'].fillna('empty')

df = df.sort_values(by=['label'])
# #Replacing missing labels with -1
df['label'] = df['label'].fillna(-1).astype(int)

df = df.drop_duplicates()

df = df[df.label!=-1]

df['concatenated'] = df['left_context'] + ' | ' + df['recovered_gram'] + ' | ' + df['right_context']
print('Number of annotated rows ',df.shape[0])
df
# Out:
# ...
# 100%|██████████| 7438/7438 [00:00<00:00, 382005.38it/s]
# Number of annotated rows  8721
#                                              left_context  \
# 0       be look for a temporary opportunity within a p...
# 5214                  our client be one of the uk s lead
# 5213    further mechanical maintenance engineer to the...
# 5211              for over 30 year this client be a lead
# 5210    you will be responsible for lead the clinical ...
# ...                                                   ...
# 330427                                 project management
# 237822                                              empty
# 237823                                              empty
# 237738                                              empty
# 6796                                                empty
#
#                          recovered_gram  \
# 0                               dynamic
# 5214                        independent
# 5213                       team to work
# ...

# %%
from nltk import RegexpTokenizer
def word2vec_vocab_check(text):
    tokenizer = RegexpTokenizer(r'\w+')
    tokens =  tokenizer.tokenize(text)
    try:
        word2vec.wv[tokens]
        return True
    except:
        return False

#Function to retrieve word2vec vectors from spacy
def word2vec_retriever_sum(text):
    tokenizer = RegexpTokenizer(r'\w+')
    tokens =  tokenizer.tokenize(text)
    wordvectors = sum(word2vec.wv[tokens])
    return wordvectors
    
def word2vec_retriever_average(text):
    tokenizer = RegexpTokenizer(r'\w+')
    tokens =  tokenizer.tokenize(text)
    wordvectors = word2vec.wv[tokens]
    average = sum(wordvectors)/len(wordvectors)
    return average

# %%
#Removing out of vocabulary word2vec words
df['vocab_check_left'] = df['left_context'].progress_apply(word2vec_vocab_check)
df['vocab_check_middle'] = df['recovered_gram'].progress_apply(word2vec_vocab_check)
df['vocab_check_right'] = df['right_context'].progress_apply(word2vec_vocab_check)
df = df[(df.vocab_check_left==True) & (df.vocab_check_middle==True) & (df.vocab_check_right==True)]
df = df.drop(columns=['vocab_check_left', 'vocab_check_middle', 'vocab_check_right'])
df
# Out:
#   0%|          | 0/8721 [00:00<?, ?it/s]<ipython-input-4-cd24b054c66e>:6: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   word2vec.wv[tokens]
# ...
# 100%|██████████| 8721/8721 [00:00<00:00, 34327.47it/s]
#                                              left_context  \
# 0       be look for a temporary opportunity within a p...
# 5213    further mechanical maintenance engineer to the...
# 5211              for over 30 year this client be a lead
# 5210    you will be responsible for lead the clinical ...
# 5209                                         rfi rfp bid
# ...                                                   ...
# 330427                                 project management
# 237822                                              empty
# 237823                                              empty
# 237738                                              empty
# 6796                                                empty
#
# ...

# %%
mode = word2vec_retriever_average
#Retrieving the word2vec vectors
x_left = pd.DataFrame(df['left_context'].progress_apply(mode))
x_left = x_left['left_context'].progress_apply(pd.Series)

#Retrieving the word2vec vectors
x_right = pd.DataFrame(df['right_context'].progress_apply(mode))
x_right = x_right['right_context'].progress_apply(pd.Series)

#Retrieving the word2vec vectors
x_middle = pd.DataFrame(df['recovered_gram'].progress_apply(mode))
x_middle = x_middle['recovered_gram'].progress_apply(pd.Series)

x = x_left
x['sep'] = 222
x = x.join(x_middle,lsuffix='_left', rsuffix='_middle')
x['sep2'] = 222
x = x.join(x_right,lsuffix='_middle', rsuffix='_right')

x
# Out:
#   0%|          | 0/7832 [00:00<?, ?it/s]<ipython-input-4-cd24b054c66e>:21: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   wordvectors = word2vec.wv[tokens]
# ...
# 100%|██████████| 7832/7832 [00:01<00:00, 4739.00it/s]
#           0_left    1_left    2_left    3_left    4_left    5_left    6_left  \
# 0      -0.099833  0.020272 -0.102918 -0.182999 -0.011581 -0.069055  0.157539
# 5213    0.029924 -0.032267 -0.197287 -0.236153 -0.430727 -0.167721  0.151823
# 5211   -0.280737  0.175655 -0.039274 -0.099817 -0.068903  0.046741  0.074522
# 5210   -0.114807  0.245052  0.039652 -0.224733 -0.085270  0.088978 -0.033981
# 5209    0.182049 -0.150913 -0.135940  0.407682  0.131014 -0.231643  0.033206
# ...          ...       ...       ...       ...       ...       ...       ...
# 330427 -0.094983 -0.012433  0.076395 -0.294565  0.263263 -0.432904  0.352220
# 237822  0.178320  0.401110 -0.445910 -0.227490  0.012694  0.133020  0.145320
# ...

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_validate
from statistics import mean
dummy_clf = DummyClassifier(strategy="stratified")

performance_measures = ['precision_macro', 'recall_macro','f1_macro']
scores = cross_validate(dummy_clf, x, df['label'], scoring=performance_measures,cv=10,n_jobs=-1)

average_precision = mean(scores['test_precision_macro'])
average_recall = mean(scores['test_recall_macro'])
average_f1 = mean(scores['test_f1_macro'])

print(average_precision)
print(average_recall)
print(average_f1)
# Out:
# 0.3372724520424926
# 0.33758887198215026
# 0.3372416967281033

# %%
df['pos'] = df['recovered_gram'].progress_apply(functions.pos_tagger)
df['pos'] = df['pos'].progress_apply(functions.sequence_counter)

pos_dicts = df[['pos']]
pos_dicts = pos_dicts['pos'].apply(pd.Series)
pos_dicts = pos_dicts.fillna(0).astype(int)

df['dep'] = df['recovered_gram'].progress_apply(functions.dep_tagger)
df['dep'] = df['dep'].progress_apply(functions.sequence_counter)

dep_dicts = df[['dep']]
dep_dicts = dep_dicts['dep'].apply(pd.Series)
dep_dicts = dep_dicts.fillna(0).astype(int)

x_pos = pos_dicts.join(dep_dicts,lsuffix='_gram', rsuffix='_pos')

x = x.join(x_pos, lsuffix='_embedding', rsuffix='_pos')
# Out:
# ...
# 100%|██████████| 7832/7832 [00:53<00:00, 147.49it/s]

# %%
from sklearn.dummy import DummyClassifier
from sklearn.model_selection import cross_validate
from statistics import mean
dummy_clf = DummyClassifier(strategy="stratified")

performance_measures = ['precision_macro', 'recall_macro','f1_macro']
scores = cross_validate(dummy_clf, x, df['label'], scoring=performance_measures,cv=10,n_jobs=-1)

average_precision = mean(scores['test_precision_macro'])
average_recall = mean(scores['test_recall_macro'])
average_f1 = mean(scores['test_f1_macro'])

print(average_precision)
print(average_recall)
print(average_f1)
# Out:
# 0.3214391421449514
# 0.32179554504258806
# 0.3215522711818418

# %%
functions.confusion_matrix(dummy_clf,x,df['label'])
