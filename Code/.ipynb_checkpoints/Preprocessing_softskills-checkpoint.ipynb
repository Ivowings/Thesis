# %%
import pandas as pd
from flashtext import KeywordProcessor
import spacy
import sys
import re
pd.set_option("display.max_rows", None, "display.max_columns", None)
nlp = spacy.load("en_core_web_sm")

# %%
df3 = pd.read_excel('/Users/ivowings/Sync/Thesis/Datasources/Skills/soft_skills_buildingasoftskilltaxonomy.xlsx')

# %%
df3 = df3['Soft skill, Alternative labels'].str.split(' ', 1, expand=True)
df3 = df3.rename(columns={0: "soft_skill", 1: "alternative_labels"})
df3['soft_skill'] = df3['soft_skill'].str.replace(',', '')

# %%
#Only selecting the alternative labels
df3 = pd.DataFrame(df3['alternative_labels'])

# %%
#Creating the softskills list
df3 = df3['alternative_labels'].str.split(',', expand=True).values.flatten()
df3 = pd.DataFrame({'alternative_labels':df3})
df3 = df3[df3.alternative_labels.isna()==False].reset_index()
#Lowercasing all skills
df3 = pd.DataFrame(df3['alternative_labels'].str.lower())

# %%
#Combining all dfs
softskills = pd.concat([df3])

# %%
#Removing trailing whitespaces
#softskills['soft_skill'] = softskills['soft_skill'].str.replace('-', '')
softskills['alternative_labels'] = softskills['alternative_labels'].str.strip()

# %%
#Lemmatizing the text
def lemmatizer(text):
    doc = nlp(str(text))
    text = ' '.join([token.lemma_ if token.lemma_ != '-PRON-' else token.text for token in doc])
    return text

#softskills['soft_skill'] = softskills['soft_skill'].apply(lemmatizer)

softskills.drop_duplicates(subset=None, keep="first", inplace=True)
softskills = softskills.reset_index(drop=True)

# %%
softskills = softskills.rename(columns={'alternative_labels' : 'soft_skill'})

# %%
softskills.to_csv("/Users/ivowings/Sync/Thesis/Datasources/Preprocessed/softskills.csv", index=False)

# %%
softskills
# Out:
#                       soft_skill
# 0               responsibilities
# 1                 responsibility
# 2                  transparently
# 3                    responsible
# 4                 accountability
# 5                   transparency
# 6                    transparent
# 7                 transparencies
# 8                    accountable
# 9                        account
# 10              accountabilities
# 11                     listening
# 12                       listens
# 13                        listen
# 14                  communicator
# 15                 social skills
# 16           conflict resolution
# 17                communications
# 18                      listener
# 19                   communicate
# 20                 communication
# 21              active listening
# 22                  adaptability
# 23                      adaptive
# 24                      stressed
# 25                         adapt
# 26                     adaptable
# 27                     stressful
# 28                        stress
# 29                      stresses
# 30                      adapting
# 31                     synthesis
# 32                  analytically
# 33                    analytical
# 34                      analytic
# 35             analytical skills
# 36                     analytics
# 37                  interpreting
# 38                     interpret
# 39                        debate
# 40                       opinion
# 41                     logically
# 42                     arguments
# 43                       logical
# 44                       debated
# 45                   opinionated
# 46                   interpreted
# 47                      debating
# 48                      argument
# 49                         logic
# 50                      opinions
# 51                       debates
# 52                interpretation
# 53                        logics
# 54                 argumentation
# 55                      coaching
# 56                       coaches
# 57        performance management
# 58                       coached
# 59                     sprinting
# 60                         coach
# 61                       sprints
# 62                        sprint
# 63                    commitment
# 64                   commitments
# 65                     committed
# 66                        commit
# 67                   interactive
# 68          communication skills
# 69                understandable
# 70                 interpersonal
# 71                 understanding
# 72               interpersonally
# 73                 communicating
# 74                      interact
# 75                    understand
# 76                interpersonals
# 77                   interacting
# 78            open communication
# 79                   interaction
# 80                   understands
# 81   interpersonal communication
# 82                      paradigm
# 83                 conceptualize
# 84                  conceptually
# 85                        primes
# 86                    pragmative
# 87                    conceptual
# 88                      concepts
# 89                    pragmatism
# 90                    concepting
# 91                        primed
# 92             conceptualization
# 93                 conceptualism
# 94                 pragmatically
# 95                     paradigms
# 96                     pragmatic
# 97                    conception
# 98                       concept
# 99                       priming
# 100                        prime
# 101                   management
# 102          conflict management
# 103                  counselling
# 104                     counsels
# 105                      counsel
# 106                   counseling
# 107                 coordinating
# 108                 coordination
# 109                  coordinated
# 110                  coordinator
# 111                   coordinate
# 112                     original
# 113                     geniuses
# 114                      musical
# 115            creative thinking
# 116                   originally
# 117                     insights
# 118                      imagine
# 119                    ingenuous
# 120                    creatives
# 121                     innovate
# 122                   imaginable
# 123                  origination
# 124                   insightful
# 125     thinking outside the box
# 126                   creatively
# 127                   innovation
# 128                        music
# 129                       genius
# 130                  originality
# 131                     creative
# 132                   creativity
# 133                       musics
# 134               graphic design
# 135                    intellect
# 136                   innovative
# 137                     musicals
# 138                  imagination
# 139                  innovations
# 140                      insight
# 141                 insightfully
# 142                    ingenuity
# 143                  imaginative
# 144                     thinking
# 145              rationalization
# 146                intellectuals
# 147                   reasonable
# 148                   rationally
# 149                      thought
# 150                       critic
# 151                     humanism
# 152                   reasonably
# 153                   critically
# 154                     thoughts
# 155                  rationality
# 156                       reason
# 157            critical thinking
# 158               intellectually
# 159                      critics
# 160                  criticality
# 161                    relevance
# 162                     rational
# 163                     critical
# 164                    relevancy
# 165                    foresight
# 166                    reasoning
# 167                 thoughtfully
# 168               advanced level
# 169                   thoughtful
# 170                 intellectual
# 171                      reasons
# 172                     relevent
# 173                     relevant
# 174                    criticism
# 175                inquisitional
# 176                      curious
# 177                    curiosity
# 178                   curiousity
# 179                   interested
# 180                  inquisitive
# 181                  interesting
# 182              inquisitiveness
# 183                     interest
# 184                  inquisition
# 185                    interests
# 186                      discern
# 187                     decision
# 188                    decisions
# 189                     decisive
# 190                   judgmental
# 191                   discerning
# 192                  discernment
# 193                    discerned
# 194                     judgment
# 195                    judgments
# 196                  decisioning
# 197                  discernible
# 198              judgmentability
# 199                       making
# 200                 data quality
# 201                   estimation
# 202                       action
# 203                        costs
# 204                     actioned
# 205                   actionable
# 206                     advocacy
# 207              decision making
# 208                    intuitive
# 209                     estimate
# 210                       intuit
# 211              data governance
# 212                  memorandums
# 213                    estimator
# 214                   estimating
# 215                         pros
# 216        business intelligence
# 217                     costings
# 218                      costing
# 219                         cost
# 220                  intuitively
# 221                      actions
# 222                    estimates
# 223                   memorandum
# 224                    intuition
# 225                      details
# 226                       detail
# 227                    detailing
# 228                     detailed
# 229                    diversify
# 230                  diversifies
# 231             multiculturalism
# 232                      diverse
# 233                    diversion
# 234                   diversions
# 235                multicultural
# 236                  diversified
# 237                multicultured
# 238                 multiculture
# 239                    diversity
# 240                 diversifying
# 241                  persistence
# 242                      persist
# 243                 persistently
# 244                        eager
# 245                      eagerly
# 246                   persistent
# 247                    eagerness
# 248                 intelligence
# 249                   motivating
# 250                      empathi
# 251                     motivate
# 252       emotional intelligence
# 253                    motivated
# 254                      empathy
# 255                   motivation
# 256                    enthusing
# 257                    emotional
# 258                     spirited
# 259                      enthuse
# 260                 enthusiastic
# 261                       spirit
# 262                spiritability
# 263                     enthused
# 264             enthusiastically
# 265            enthusiasmability
# 266                    enjoyment
# 267                  emotionally
# 268                     enthuses
# 269                     enjoying
# 270                       enjoys
# 271                   enthusiasm
# 272                     emotions
# 273                      spirits
# 274                   enthusiast
# 275                    enjoyable
# 276                  enthusiasts
# 277                      emotion
# 278                        enjoy
# 279                       ethics
# 280                      respect
# 281                    respected
# 282                    ethically
# 283                   respectful
# 284                   respective
# 285                      ethical
# 286                        ethic
# 287                     flexibly
# 288                flexibilities
# 289                  flexibility
# 290                     flexible
# 291                      purpose
# 292                      profits
# 293                      planned
# 294                   milestoned
# 295                  action plan
# 296                   purposeful
# 297                   milestones
# 298                       desire
# 299                    milestone
# 300                        goals
# 301                      objects
# 302                      desired
# 303                       object
# 304                        plans
# 305            primary objective
# 306                    purposely
# 307                    objective
# 308                       goaled
# 309                profitability
# 310                   objectives
# 311            mission statement
# 312                       profit
# 313                         goal
# 314                   profitable
# 315                         plan
# 316                   desireable
# 317                     planning
# 318                     purposes
# 319                    desirable
# 320                       hotels
# 321                   bartenders
# 322                hotel manager
# 323                 entertaining
# 324                  hospitality
# 325                      bartend
# 326                       guests
# 327                    entertain
# 328                        hotel
# 329         hospitality industry
# 330                   hospitable
# 331           revenue management
# 332                entertainment
# 333                        guest
# 334                    bartender
# 335               entertainments
# 336                   bartending
# 337                  impartially
# 338                  objectivity
# 339                    impartial
# 340                 impartiality
# 341                influentially
# 342                 persuasively
# 343                   influencer
# 344                   influences
# 345                  influencing
# 346                    influence
# 347                   persuasive
# 348                  influential
# 349                   persuasion
# 350               persuasiveness
# 351                    initiator
# 352                   initiative
# 353                      initial
# 354                  initiatives
# 355                    initially
# 356              confidentiality
# 357                      trusted
# 358                   integrated
# 359                     credibly
# 360                        trust
# 361                   accuracies
# 362                       trusts
# 363                    integrity
# 364               data integrity
# 365                     trusting
# 366                  credibility
# 367                 confidential
# 368                      honesty
# 369            confidentialities
# 370                     accuracy
# 371               confidentially
# 372                     credible
# 373                people skills
# 374              public speaking
# 375                      warming
# 376                     kindness
# 377                        kinds
# 378                        warms
# 379                     patience
# 380                         warm
# 381                   compassion
# 382                       kindly
# 383                       warmly
# 384                         kind
# 385         leadership qualities
# 386            leadership skills
# 387                   facilitate
# 388                  facilitates
# 389                   leadership
# 390                  leaderships
# 391       leadership development
# 392                 facilitating
# 393              business acumen
# 394          leadership position
# 395                 facilitation
# 396          succession planning
# 397                    onboarded
# 398                      onboard
# 399                     mentored
# 400                       mentor
# 401                    mentoring
# 402                   onboarding
# 403                      mentors
# 404                  onboardings
# 405                   mentorship
# 406       management development
# 407                   negotiable
# 408           negotiation skills
# 409                     arbitral
# 410                    procuring
# 411                     procured
# 412                 arbitrations
# 413                  procurement
# 414                      mediate
# 415                    mediating
# 416                 negotiations
# 417                    arbitrate
# 418                  negotiating
# 419                    negotiate
# 420                     mediator
# 421                      procure
# 422                    diplomacy
# 423                   negotiator
# 424                    mediation
# 425                  arbitration
# 426                  negotiation
# 427                     optimist
# 428            positive attitude
# 429                   optimistic
# 430                     optimism
# 431                  personality
# 432                       person
# 433           oral communication
# 434                        orals
# 435                      oralism
# 436                         oral
# 437                       orally
# 438                      passion
# 439                   passionate
# 440                     passions
# 441                     passione
# 442                 passionately
# 443                     persuade
# 444                   persuading
# 445                    persuades
# 446                    persuader
# 447                   presenting
# 448              audienceability
# 449                    audiences
# 450                   exhibition
# 451                      present
# 452                      audienc
# 453                presentations
# 454                 presentation
# 455                     exhibits
# 456                  exhibitions
# 457                     audience
# 458           sales presentation
# 459                      exhibit
# 460                      solving
# 461             problem analysis
# 462                     probleme
# 463                      problem
# 464               troubleshooter
# 465              troubleshooting
# 466                decomposition
# 467                troubleshoots
# 468              problem solving
# 469                 troubleshoot
# 470                     problems
# 471           problem management
# 472                  self-esteem
# 473                  confidently
# 474                    confident
# 475                    confidant
# 476              self-confidence
# 477               self-confident
# 478                   confidence
# 479               self-organized
# 480                       skills
# 481                assertiveness
# 482                  assertively
# 483         interpersonal skills
# 484                       assert
# 485                    assertive
# 486                  life skills
# 487                        speak
# 488                     speaking
# 489                       speech
# 490                       speaks
# 491                     speeches
# 492                 strategizing
# 493                   strategies
# 494           strategic thinking
# 495                   strategize
# 496                     strategy
# 497                strategically
# 498                    strategie
# 499            business planning
# 500                    strategys
# 501           strategic planning
# 502                    strategic
# 503                         team
# 504                        teams
# 505                    synergies
# 506                      teaming
# 507              collaboratively
# 508                    cooperate
# 509                    teamworks
# 510                   teamworker
# 511                collaboration
# 512                collaborative
# 513                cooperatively
# 514                  collaborate
# 515                  team player
# 516                  cooperation
# 517                     teamwork
# 518                     synergis
# 519                  cooperative
# 520                      synergy
# 521                team building
# 522                  teamworking
# 523                       teamed
# 524                      synergi
# 525                  punctuality
# 526                         task
# 527                       tasked
# 528                      tasking
# 529                   punctually
# 530              time management
# 531                     punctual
# 532             project planning
# 533                        tasks
# 534              trustworthiness
# 535                  trustworthy
# 536         verbal communication
# 537                    authoring
# 538                    proofread
# 539                   translated
# 540                 publications
# 541                 social media
# 542                       record
# 543                    recording
# 544                 proofreading
# 545                   journalism
# 546                      grammar
# 547                   journaling
# 548                     journals
# 549                     spelling
# 550                  authorities
# 551                      spelled
# 552                      records
# 553                        spell
# 554                      journal
# 555                    publicity
# 556                       public
# 557                    translate
# 558                      writers
# 559                        write
# 560                      writing
# 561                      texting
# 562                       writer
# 563                       writes
# 564                       author
# 565                  publication
# 566                     recorded
# 567               grammarability
# 568                  proofreader
# 569                       spells
# 570                  translation
# 571                   proofreads
# 572                 white papers
# 573                     grammars
# 574                        texts
# 575                  translating
# 576                    authority
# 577                         text
# 578                     writings
# 579        written communication
